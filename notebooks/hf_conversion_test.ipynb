# %%
from transformers import AutoTokenizer, AutoModelForCausalLM, TextStreamer

# %%
model_name = "/raid/s3/opengptx/behzad_shomali/hf_converted/fineweb2_edu_pondering_pythia/"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForCausalLM.from_pretrained(pretrained_model_name_or_path=model_name, dtype="auto", device_map="auto", trust_remote_code=True)
streamer = TextStreamer(tokenizer, skip_prompt=True, skip_special_tokens=True)

# %%
input_text = "The capital of Italy is the city of"
inputs = tokenizer(input_text, return_tensors="pt").to(model.device)

# %%
outputs = model.generate(
    **inputs, 
    max_new_tokens=50, 
    do_sample=True, 
    top_p=0.9, 
    temperature=0.3,
    streamer=streamer
)
# print(tokenizer.decode(outputs[0], skip_special_tokens=True))
# Out:
# Milan, and the capital of Italy is the capital of Italy.
# The city of Milan is the capital of Italy. Milan is the capital of Italy. Milan is the capital of Italy. Milan is the capital of Italy. Milan is the capital of

# %%
tokenizer.decode([     2,   6507,    528,    448,  22051,    512, 250428, 250521, 250467, 250672, 250478, 250565])
# Out:
# '<s> What is the answer of 50+2='

# %%
"fineweb2_edu_pondering3_pythia".split("pondering")[0]
# Out:
# ['fineweb2_edu_', '3_pythia']
